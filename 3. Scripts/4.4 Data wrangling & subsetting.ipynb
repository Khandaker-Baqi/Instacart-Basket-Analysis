# %% [markdown]
# # Importing Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %% [markdown]
# ## Defining Path Variable

# %%
# defining path
path = r'C:\Users\khand\Desktop\Careerfoundry\Data Immersion\Achievement - 4\04-2022 Instacart Basket Analysis'

# %% [markdown]
# ## Importing "orders.csv"

# %%
# importing "orders.csv"
df_ords = pd.read_csv(os.path.join(path, '2. Data', 'Original Data', 'orders.csv'), index_col = False)

# %% [markdown]
# ## Importing "products.csv"

# %%
# importing "products.csv"
df_prods = pd.read_csv(os.path.join(path, '2. Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Top 5 rows of df_ords
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Deleting the unwanted columns from dataframe
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# frequency distribution of the 'days_since_prior_order' column
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# ## Overwriting the dataframe permanently

# %%
# Permanently deleting the unwanted column from the dataset
df_ords = df_ords.drop(columns = ['eval_set'])

# %% [markdown]
# ## Renaming the clumn 'order_dow' to 'order_day_of_week'

# %%
# renaming a column
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## Changing data type of 'order_id' column to 'str'

# %%
# Changing datatype of a column
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %% [markdown]
# ### Checking data type of the 'orders_id' column

# %%
# Checking data type
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Importing 'departments.csv'

# %%
# Importing the "departments.csv" dataframe
df_dep = pd.read_csv(os.path.join(path, '2. Data', 'Original Data', 'departments.csv'))

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Creating a data dictionary

# %% [markdown]
# ### Transposing the 'df_dep' data frame

# %%
# Transposing the dataframe
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ## Permanently overwriting the 'df_dep' dataframe in long format

# %%
# Permanentry transposing the dataframe
df_dep = df_dep.T

# %%
df_dep.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %% [markdown]
# ## Adding index to dataframe 'df_data'

# %%
Adding index to the dataframe
df_dep.reset_index()
# Out:
#   File "C:\Users\khand\AppData\Local\Temp/ipykernel_20004/3153433789.py", line 1
#     Adding index to the dataframe
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Assigning the first row as value of variable "new_header"

# %%
# Assigning the values in the first row to the "new_header" variable
new_header = df_dep.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %% [markdown]
# ### Turning the row 1 and beyond in to new dataframe

# %%
# turning the records in row 1 and beyond into a new dataframe
df_dep_t_new = df_dep[1:]

# %%
df_dep_t_new.head()
# Out:
#          0
# 1   frozen
# 2    other
# 3   bakery
# 4  produce
# 5  alcohol

# %% [markdown]
# ### Assigning the values of "new_header" variable as the column names of the new database

# %%
# Assigning the values of the "new_header" variable as column headers
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ### Turning the new dataframe into a data dictionary

# %%
# Turing the dataframe into a data dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# ## Looking for records with "department_id" of 19

# %%
# Searching for records with department id: 19
df_prods['department_id'] == 19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %% [markdown]
# ## Isolating only the records with "department_id" of 19

# %%
# filtering records with department id: 19
df_prods[df_prods['department_id'] == 19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# ## Turning the filtered portion of the dataframe into a new dataframe

# %%
# turning the filtered records into a new dataframe
df_snacks = df_prods[df_prods['department_id'] == 19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# ## Using the loc function to filter

# %%
# Using the loc function to filter
df_prods.loc[df_prods['department_id'] == 19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# ## Using isin([]) to filter with multiple values/list

# %%
# Using isin([]) to filter
df_prods.loc[df_prods['department_id'].isin([19])]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# # Exporting dataframes

# %%
df_ords.to_csv(os.path.join(path, '2. Data', 'Prepared Data', 'Orders_prepared.csv'), index = None)

# %%
df_snacks.to_csv(os.path.join(path, '2. Data', 'Prepared Data', 'Snacks.csv'), index = None)

# %%
df_dep_t_new.to_csv(os.path.join(path, '2. Data', 'Prepared Data', 'Data_dictionary.csv'), index = None)

# %% [markdown]
# # Task 4.4

# %%
df_ords.head()
# Out:
#   order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                  2                  8
# 1  2398795        1             2                  3                  7
# 2   473747        1             3                  3                 12
# 3  2254736        1             4                  4                  7
# 4   431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## Changing data types of Identifier variables

# %%
# Changing data type of "order_id" variable to "string"
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# Changing data type of "user_id" variable to "sting"
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Checking data type of "order_id" variable
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
# Checking data type of "user_id" variable
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Changing column name

# %%
# Changing the name of the "order_hour_of_day" column
df_ords.rename(columns = {'order_hour_of_day' : 'order_time_24h_format'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_time_24h_format  \
# 0  2539329       1             1                  2                      8
# 1  2398795       1             2                  3                      7
# 2   473747       1             3                  3                     12
# 3  2254736       1             4                  4                      7
# 4   431534       1             5                  4                     15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## Finding the busiest hour of the day

# %%
# Finding the frequency of the values in the "order_time_hour_of_day" 
df_ords['order_time_24h_format'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_time_24h_format, dtype: int64

# %% [markdown]
# #### The value 10 has the highest frequency, meaning 10 am is the busiest hour of the day in terms of order numbers

# %% [markdown]
# ## Determining the meaning of the value '4' in the "department_id" column

# %%
# Printing the value corresponding to the department id: "4"
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ## Subsetting order data from only breakfast department

# %%
#Printing the whole data dictionary
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# #### "breakfast" items are represented by the value "14" in the "department_id" column

# %% [markdown]
# ### Subsetting the "breakfast" data

# %%
# Filtering only the records with "department_id" of "14" from the "df_prods" dataframe
df_prods.loc[df_prods['department_id'].isin([14])]
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# Turning the filtered "breakfast" department data in to new dataframe
df_breakfast = df_prods.loc[df_prods['department_id'].isin([14])]

# %%
# Finding the number of rows and columns in the dataframe
df_breakfast.shape
# Out:
# (1116, 5)

# %% [markdown]
# #### The "df_breakfast" dataframe has 1116 records.

# %% [markdown]
# ### Subsetting the "dinner party" data

# %%
# Filtering the records with department_id 5, 7, 12, 20 which refer to "alchohol", "beverage", "meat/seafood" and "deli"
df_prods.loc[df_prods['department_id'].isin([5, 7, 12, 20])]
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# Turining the filtered data in to a new dataframe
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5, 7, 12, 20])]

# %%
# finding the numner of rows and columns in the "df_dinner_party" dataset
df_dinner_party.shape
# Out:
# (7650, 5)

# %% [markdown]
# #### The "df_dinner_party" dataframe has 7650 records

# %% [markdown]
# ### Subsetting records that have "1" as value in the "user_id" column.

# %%
# Filtering the records with user id: 1
df_ords.loc[df_ords['user_id'].isin(['1'])]
# Out:
#    order_id user_id  order_number  order_day_of_week  order_time_24h_format  \
# 0   2539329       1             1                  2                      8
# 1   2398795       1             2                  3                      7
# 2    473747       1             3                  3                     12
# 3   2254736       1             4                  4                      7
# 4    431534       1             5                  4                     15
# 5   3367565       1             6                  2                      7
# 6    550135       1             7                  1                      9
# 7   3108588       1             8                  1                     14
# 8   2295261       1             9                  1                     16
# 9   2550362       1            10                  4                      8
# 10  1187899       1            11                  4                      8
#
#     days_since_prior_order
# 0                      NaN
# ...

# %%
# Turning the filtered records in to a separate dataframe
df_user_id_1 = df_ords.loc[df_ords['user_id'].isin(['1'])]

# %% [markdown]
# ### Basic statistics of the records under user id: 1

# %%
# Number of rows and columns in the "df_user_id_1" dataframe
df_user_id_1.shape
# Out:
# (11, 6)

# %%
# Descriptive analysis of the "df_user_id_1" dataframe
df_user_id_1.describe()
# Out:
#        order_number  order_day_of_week  order_time_24h_format  \
# count     11.000000          11.000000              11.000000
# mean       6.000000           2.636364              10.090909
# std        3.316625           1.286291               3.477198
# min        1.000000           1.000000               7.000000
# 25%        3.500000           1.500000               7.500000
# 50%        6.000000           3.000000               8.000000
# 75%        8.500000           4.000000              13.000000
# max       11.000000           4.000000              16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# ## Exporting dataframes

# %%
# Exporting dataframe "df_ords"
df_ords.to_csv(os.path.join(path, '2. Data', 'Prepared Data', 'orders_wrangled.csv'), index = None)

# %%
# Exporting dataframe "df_dep_t_new"
df_dep_t_new.to_csv(os.path.join(path, '2. Data', 'Prepared Data', 'departments_wrangled.csv'), index = None)

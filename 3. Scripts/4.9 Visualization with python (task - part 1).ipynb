# %% [markdown]
# # Task 4.9 - Part 1

# %% [markdown]
# ## Importing libraries

# %%
# imporitng libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Defining path variable

# %%
path = r"C:\Users\khand\Desktop\Careerfoundry\Data Immersion\Achievement - 4\04-2022 Instacart Basket Analysis"

# %% [markdown]
# ## Importing dataframe

# %%
# importing dataframe
df_customers = pd.read_csv(os.path.join(path, '2. Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# ## Data wrangling steps

# %% [markdown]
# ### Checking column names, datatypes and number of rows and columns

# %%
# checking column names, datatypes and number of rows and columns
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# ### Checking for number of null values in each column

# %%
# checking for number of null values in each column
df_customers.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %% [markdown]
# ### Checking the first 50 rows of the dataframe

# %%
# checking the first 50 rows of the dataframe
df_customers.head(50)
# Out:
#     user_id   First Name     Surnam  Gender           STATE  Age date_joined  \
# 0     26711      Deborah   Esquivel  Female        Missouri   48    1/1/2017
# 1     33890     Patricia       Hart  Female      New Mexico   36    1/1/2017
# 2     65803      Kenneth     Farley    Male           Idaho   35    1/1/2017
# 3    125935     Michelle      Hicks  Female            Iowa   40    1/1/2017
# 4    130797          Ann    Gilmore  Female        Maryland   26    1/1/2017
# 5    133128      Cynthia      Noble  Female        Kentucky   43    1/1/2017
# 6    152052        Chris     Walton    Male         Montana   20    1/1/2017
# 7    168851       Joseph    Hickman    Male  South Carolina   30    1/1/2017
# 8     69965       Jeremy       Vang    Male           Texas   47    1/1/2017
# 9     82820        Shawn      Chung    Male        Virginia   26    1/1/2017
# 10    26441       Gloria   Stafford  Female          Nevada   19    1/1/2017
# ...

# %% [markdown]
# ### Checking the frequency distribution of the "date_joined" column

# %%
# checking the frequency distibution of the 'date_joined' column
df_customers['date_joined'].value_counts(dropna = False)
# Out:
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
#              ...
# 9/1/2018      141
# 1/22/2018     140
# 11/24/2017    139
# 7/18/2019     138
# 8/6/2018      128
# Name: date_joined, Length: 1187, dtype: int64

# %% [markdown]
# ### Renaming columns

# %%
# renaming the "Surnam" column
df_customers.rename(columns = {'Surnam' : 'surname'}, inplace = True)

# %%
# renaming the 'n_dependants' column
df_customers.rename(columns = {'n_dependants' : 'number_of_dependatns'}, inplace = True)

# %%
# renaming the "fam_status" column
df_customers.rename(columns = {'fam_status' : 'family_status'}, inplace = True)

# %%
# renaming the "First Name" column
df_customers.rename(columns = {'First Name' : 'first_name'}, inplace = True)

# %%
# renaming the "Gender" column
df_customers.rename(columns = {'Gender' : 'gender'}, inplace = True)

# %%
# renaming the "STATE" column
df_customers.rename(columns = {'STATE' : 'state'}, inplace = True)

# %%
# renaming the "Age" column
df_customers.rename(columns = {'Age' : 'age'}, inplace = True)

# %% [markdown]
# ### Checking the column names

# %%
# checking the column names
df_customers.columns
# Out:
# Index(['user_id', 'first_name', 'surname', 'gender', 'state', 'age',
#        'date_joined', 'number_of_dependatns', 'family_status', 'income'],
#       dtype='object')

# %% [markdown]
# ### Changing the data type of the "'user_id" column

# %%
# changing the datatype of the "user_id" column to "str"
df_customers['user_id'] = df_customers['user_id'].astype('str')

# %% [markdown]
# ### Checking the updated datatypes of the columns

# %%
# checking the datatypes of the columns
df_customers.dtypes
# Out:
# user_id                 object
# first_name              object
# surname                 object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependatns     int64
# family_status           object
# income                   int64
# dtype: object

# %% [markdown]
# ## Data consistency checks

# %% [markdown]
# ### Filtering only the records with null values in "first_name" column

# %%
# filtering the records with null values in "first_name" column
df_null = df_customers[df_customers['first_name'].isnull() == True]

# %% [markdown]
# ### Checking the records with null values

# %%
# checking the first 50 rows of the "df_null" dataframe
df_null.head(50)
# Out:
#     user_id first_name     surname  gender                 state  age  \
# 53    76659        NaN     Gilbert    Male              Colorado   26
# 73    13738        NaN       Frost  Female             Louisiana   39
# 82    89996        NaN      Dawson  Female                Oregon   52
# 99    96166        NaN     Oconnor    Male              Oklahoma   51
# 105   29778        NaN      Dawson  Female                  Utah   63
# 128    8562        NaN     Oconnor    Male                  Utah   46
# 140  149267        NaN  Hutchinson    Male        South Carolina   20
# 149   82632        NaN         Orr    Male                Hawaii   61
# 155  172331        NaN  Williamson  Female                Alaska   27
# 236  182963        NaN   Nicholson  Female            New Mexico   58
# 241   49727        NaN       Moran    Male                Alaska   53
# 265   63554        NaN  Williamson  Female              Delaware   49
# ...

# %% [markdown]
# ### Checking the mixed datatype columns

# %%
# checking for mixed data type columns
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# ### Changing the datatype of the mixed data type columns

# %%
# changing the data type of the "first_name" column
df_customers['first_name'] = df_customers['first_name'].astype('str')

# %% [markdown]
# ### Checking for duplicate records

# %%
# checking duplicate records
df_customers.loc[df_customers.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, state, age, date_joined, number_of_dependatns, family_status, income]
# Index: []

# %% [markdown]
# #### There are no duplicate records

# %% [markdown]
# ## Merging the new dataframe with the prepared dataframe

# %% [markdown]
# ### Importing prepared dataframe

# %%
# importing prepared dataframe
df_prepared = pd.read_pickle(os.path.join(path, '2. Data', 'Prepared Data', 'orders_products_merged_flagged_v2.pkl'))

# %% [markdown]
# ### Checking the imported dataframe

# %%
# checing the column names, datatypes and number of rows and columns
df_prepared.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   order_id                          object
#  1   user_id                           object
#  2   order_number                      int64
#  3   order_day_of_week                 object
#  4   order_time_24h_format             object
#  5   days_since_prior_order            float64
#  6   product_id                        object
#  7   add_to_cart_order                 int64
#  8   reordered                         int64
#  9   merge_flag_1                      category
#  10  product_name                      object
#  11  aisle_id                          object
#  12  department_id                     object
#  13  prices                            float64
#  14  _merge                            category
#  15  price_range                       object
# ...

# %% [markdown]
# ### Changing the name of the "_merge" column

# %%
# changing the name of the "_merge" column
df_prepared.rename(columns = {'_merge' : 'merge_flag_2'}, inplace = True)

# %% [markdown]
# ### Merging the data frames

# %%
# merging the dataframes
df_merged = df_prepared.merge(df_customers, on = 'user_id', how = 'left', indicator = True)

# %% [markdown]
# ### Checking the merged dataframe

# %%
# checking the null values
df_merged.isnull().sum()
# Out:
# order_id                                  0
# user_id                                   0
# order_number                              0
# order_day_of_week                         0
# order_time_24h_format                     0
# days_since_prior_order              2076096
# product_id                                0
# add_to_cart_order                         0
# reordered                                 0
# merge_flag_1                              0
# product_name                              0
# aisle_id                                  0
# department_id                             0
# prices                                    0
# merge_flag_2                              0
# price_range                               0
# busiest_day                               0
# busiest_days                              0
# busiest_period_of_the_day                 0
# max_orders                                0
# loyalty_flag                              0
# ...

# %% [markdown]
# ### Exporting the merged dataframe

# %%
# exporting the dataframe to pickle format
df_merged.to_pickle(os.path.join(path, '2. Data', 'Prepared Data', 'ords_prods_cust_merged.pkl'))
